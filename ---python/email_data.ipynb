# %% [markdown]
# # EDA Million Verifier Data

# %%
import pandas as pd

# %%
raw_df = pd.read_csv('/home/blankpanda/Documents/code-workspaces/email-validator-web-app/data/Raw/Adage.csv')
raw_df.head()
# Out:
#   First Name Last Name                    Title        Company  \
# 0      Aaron     Gaeir                      CEO    GDX Studios
# 1       Adam    Levine  New Business Consultant  Terri & Sandy
# 2        NaN       NaN                      NaN       Majority
# 3     Angela        Yu          Senior Designer           Koto
# 4        NaN       NaN                      NaN  Terri & Sandy
#
#   Company Name for Emails                                  Email Email Status  \
# 0             GDX Studios  agaeir+canned.response@gdxstudios.com     Verified
# 1           Terri & Sandy                    adam@terrisandy.com     Verified
# 2                Majority             adriana@majorityagency.com   Unverified
# 3                    Koto                     angela@koto.studio     Verified
# 4           Terri & Sandy                  ashley@terrisandy.com   Unverified
#
#    Email Confidence Catch-all Status     Email Last Verified At  ...  \
# ...

# %%
first_1000_extract = raw_df[:1000]
first_1000_extract.to_csv("Adage_first_1000.csv", index=False)

# %% [markdown]
# # Clean Data

# %%
clean_df = pd.read_csv("/home/blankpanda/Documents/code-workspaces/email-validator-web-app/data/Cleaned/Adage_FULL_REPORT_MILLIONVERIFIER.COM.csv")
clean_df.head()
# Out:
#   First Name Last Name                    Title        Company  \
# 0      Aaron     Gaeir                      CEO    GDX Studios
# 1       Adam    Levine  New Business Consultant  Terri & Sandy
# 2        NaN       NaN                      NaN       Majority
# 3     Angela        Yu          Senior Designer           Koto
# 4        NaN       NaN                      NaN  Terri & Sandy
#
#   Company Name for Emails                                  Email quality  \
# 0             GDX Studios  agaeir+canned.response@gdxstudios.com   risky
# 1           Terri & Sandy                    adam@terrisandy.com     bad
# 2                Majority             adriana@majorityagency.com     bad
# 3                    Koto                     angela@koto.studio    good
# 4           Terri & Sandy                  ashley@terrisandy.com    good
#
#       result free role  ... Last Raised At  Email Sent Email Open  \
# 0  catch_all   no   no  ...            NaN         NaN      False
# ...

# %%
Email: ashley@terrisandy.com
User: ashley
Domain: terrisandy.com
Smtp_check: true
Mx_found: true
Role: false
Disposable: false
Score: 0.8
State: deliverable
Reason: valid_mailbox
Free: false
Format_valid: true
Catch_all: null


Email: adam@terrisandy.com
User: adam
Domain: terrisandy.com
Smtp_check: false
Mx_found: true
Role: false
Disposable: false
Score: 0.64
State: undeliverable
Reason: invalid_mailbox
Free: false
Format_valid: true
Catch_all: null


{
  "tag": "canned.response",
  "free": false,
  "role": false,
  "user": "agaeir+canned.response",
  "email": "agaeir+canned.response@gdxstudios.com",
  "score": 0.8,
  "state": "deliverable",
  "domain": "gdxstudios.com",
  "reason": "valid_mailbox",
  "mx_found": true,
  "catch_all": null,
  "disposable": false,
  "smtp_check": true,
  "did_you_mean": "",
  "format_valid": true
}
